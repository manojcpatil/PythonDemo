# %%
import pandas  as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
DF=pd.DataFrame({"Treat":["A","B","C","D"]*2,"Y":np.random.randn(8)})
print(DF)
# Out:
#   Treat         Y
# 0     A -1.531578
# 1     B -2.120871
# 2     C -0.780896
# 3     D  0.226859
# 4     A -0.334832
# 5     B -0.459085
# 6     C -1.735883
# 7     D -1.420162

# %%
DF.groupby("Treat").Y.mean()
# Out:
# Treat
# A   -0.933205
# B   -1.289978
# C   -1.258390
# D   -0.596652
# Name: Y, dtype: float64

# %%
iris=pd.read_csv(r"Data\iris.csv")

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
np.unique(iris.Species)
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
colors={'Iris-setosa':'red', 'Iris-versicolor':'yellow', 'Iris-virginica':'blue'}

plt.scatter(iris.SepalLengthCm,iris.SepalWidthCm,c=iris.Species.map(colors))

# %%
! pip install scipy

# %%
import scipy.stats as ss

# %%
ss.norm.rvs(100,10,(100,5))
# Out:
# array([[ 97.27096855,  81.59976402,  89.60471542,  97.58750596,
#          90.29097038],
#        [ 86.54847795, 100.93631288, 120.47724863, 101.96239015,
#         100.65168882],
#        [ 95.84745058, 105.71250378, 110.73881688, 104.692571  ,
#         103.22033383],
#        [116.06177177,  97.43842835, 101.75200123,  90.03009717,
#          99.32108352],
#        [102.54858009, 108.59147765, 109.69737947,  96.15331994,
#         104.04953672],
#        [113.65727353, 112.97306148,  94.59843595, 105.4704257 ,
#         107.78039753],
#        [ 94.37187773, 108.0979515 , 118.69748617, 102.36591044,
#          94.6358125 ],
#        [ 96.06701012,  93.92942967,  99.46889121,  96.37250294,
#         123.58321667],
#        [ 82.35894836,  92.80603102, 115.70858208,  98.58714883,
#         106.1081578 ],
#        [109.18561624,  89.93551673, 111.06954691,  81.17610454,
#         104.9528599 ],
#        [ 94.09999891, 111.70854272,  94.25155061, 106.01968707,
# ...

# %%
x=range(10)
Px=ss.binom.pmf(x,10,0.5)
Px
# Out:
# array([0.00097656, 0.00976563, 0.04394531, 0.1171875 , 0.20507812,
#        0.24609375, 0.20507812, 0.1171875 , 0.04394531, 0.00976563])

# %%
plt.bar(x,Px)
# Out:
# <BarContainer object of 10 artists>
