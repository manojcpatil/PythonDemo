# %%
#!pip install matplotlib
import numpy as np, pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
iris=pd.read_csv("Data/Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
fig, ax = plt.subplots()
ax.plot(iris.SepalLengthCm,iris.PetalLengthCm,color='red')
plt.show()

# %%
fig, ax = plt.subplots()
iris.target=np.array([[0]*50,[1]*50,[2]*50])
ax.scatter(iris.SepalLengthCm,iris.PetalLengthCm,marker="*",c=iris.target)
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.legend()
plt.title("Sepal Length Vs Petal Length")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 3
#       1 fig, ax = plt.subplots()
#       2 iris.target=np.array([[0]*50,[1]*50,[2]*50])
# ----> 3 ax.scatter(iris.SepalLengthCm,iris.PetalLengthCm,marker=iris.target,c=iris.target)
#       4 plt.xlabel("Sepal Length")
#       5 plt.ylabel("Petal Length")
#
# File C:\Python311\Lib\site-packages\matplotlib\__init__.py:1459, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1456 @functools.wraps(func)
#    1457 def inner(ax, *args, data=None, **kwargs):
#    1458     if data is None:
# -> 1459         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1461     bound = new_sig.bind(ax, *args, **kwargs)
#    1462     auto_label = (bound.arguments.get(label_namer)
#    1463                   or bound.kwargs.get(label_namer))
#
# File C:\Python311\Lib\site-packages\matplotlib\axes\_axes.py:4629, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4627     marker_obj = marker
#    4628 else:
# -> 4629     marker_obj = mmarkers.MarkerStyle(marker)
#    4631 path = marker_obj.get_path().transformed(
#    4632     marker_obj.get_transform())
#    4633 if not marker_obj.is_filled():
#
# File C:\Python311\Lib\site-packages\matplotlib\markers.py:272, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     267     marker = ""
#     268     _api.warn_deprecated(
#     269         "3.6", message="MarkerStyle(None) is deprecated since "
#     270         "%(since)s; support will be removed %(removal)s.  Use "
#     271         "MarkerStyle('') to construct an empty MarkerStyle.")
# --> 272 self._set_marker(marker)
#
# File C:\Python311\Lib\site-packages\matplotlib\markers.py:348, in MarkerStyle._set_marker(self, marker)
#     345 elif isinstance(marker, Path):
#     346     self._marker_function = self._set_path_marker
#     347 elif (isinstance(marker, Sized) and len(marker) in (2, 3) and
# --> 348         marker[1] in (0, 1, 2)):
#     349     self._marker_function = self._set_tuple_marker
#     350 elif (not isinstance(marker, (np.ndarray, list)) and
#     351       marker in self.markers):
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
