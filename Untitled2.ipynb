# %% [markdown]
# Nonparametric Tests using
# Python
#
# \hypertarget{required-modules}{%
# \textbf{Required Modules}\label{required-modules}}
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{1}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{k+kn}{import} \PY{n+nn}{scipy}\PY{n+nn}{.}\PY{n+nn}{stats} \PY{k}{as} \PY{n+nn}{ss} \PY{c+c1}{\PYZsh{} Median\PYZus{}test, mannwhitneyu, chi2\PYZus{}contingency, spearmanr,friedmanchisquare, kruskal, ranksums, kstest,  ks\PYZus{}2samp}
# \PY{k+kn}{from} \PY{n+nn}{statsmodels}\PY{n+nn}{.}\PY{n+nn}{stats}\PY{n+nn}{.}\PY{n+nn}{descriptivestats} \PY{k+kn}{import} \PY{n}{sign\PYZus{}test} \PY{c+c1}{\PYZsh{} Sign Tests}
# \PY{k+kn}{from} \PY{n+nn}{statsmodels}\PY{n+nn}{.}\PY{n+nn}{sandbox}\PY{n+nn}{.}\PY{n+nn}{stats}\PY{n+nn}{.}\PY{n+nn}{runs} \PY{k+kn}{import} \PY{n}{runstest\PYZus{}1samp}
# \PY{c+c1}{\PYZsh{} Run test for Randomness }
# \PY{k+kn}{from} \PY{n+nn}{statsmodels}\PY{n+nn}{.}\PY{n+nn}{sandbox}\PY{n+nn}{.}\PY{n+nn}{stats}\PY{n+nn}{.}\PY{n+nn}{runs} \PY{k+kn}{import} \PY{n}{runstest\PYZus{}2samp}
# \PY{c+c1}{\PYZsh{} Run test for two samples same freq}
#
# \PY{n}{alpha}\PY{o}{=}\PY{l+m+mf}{0.05}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \hypertarget{sign-test-for-median}{%
# \section{Sign Test For Median}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test whether the population median \(M\) be regarded as \(M_0\).
#
# \hypertarget{source}{%
# \textbf{Source}} : A random sample of \(n\) observations is drawn independently. Let
# \(M_0\) be a given value to the population median.
#
# \hypertarget{assumption}{%
# \textbf{Assumption}\label{assumption}} : Each observation in the sample should be independent of each other.
#
# \hypertarget{example}{%
# \textbf{Example}}: A random sample of 15 students is selected from a school whose height
# (in cms) is given below. Test whether the median height of the school
# students be regarded as 135 or not. Test at 5\% level of significance.
#
# 132 134 138 139 142 132 140 136 135 140 139 132 131 136 138
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{2}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{Ho}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{The median height of the school students is 135 cms}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{The median height of the school students is not 135 cms}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{sample1}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{132}\PY{p}{,}\PY{l+m+mi}{134}\PY{p}{,}\PY{l+m+mi}{138}\PY{p}{,}\PY{l+m+mi}{139}\PY{p}{,}\PY{l+m+mi}{142}\PY{p}{,}\PY{l+m+mi}{132}\PY{p}{,}\PY{l+m+mi}{140}\PY{p}{,}\PY{l+m+mi}{136}\PY{p}{,}\PY{l+m+mi}{135}\PY{p}{,}\PY{l+m+mi}{140}\PY{p}{,}\PY{l+m+mi}{139}\PY{p}{,}\PY{l+m+mi}{132}\PY{p}{,}\PY{l+m+mi}{131}\PY{p}{,}\PY{l+m+mi}{136}\PY{p}{,}\PY{l+m+mi}{138}\PY{p}{]}
# \PY{n}{med}\PY{p}{,}\PY{n}{pval}\PY{o}{=}\PY{n}{sign\PYZus{}test}\PY{p}{(}\PY{n}{sample1}\PY{p}{,}\PY{n}{mu0}\PY{o}{=}\PY{l+m+mi}{35}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{M = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, pval = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{med}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)} \PY{c+c1}{\PYZsh{} M = ((N+)\PYZhy{}(N\PYZhy{}))/2}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Reject Ho: `Therefore}\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Fail to reject Ho: Therefore}\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# M = 7.500, pval = 0.000
# Conclusion - Reject Ho: `Therefore The median height of the school students is
# not 135 cms
#     \end{Verbatim}
#
#     \hypertarget{median-test-for-two-samples}{%
# \section{Median Test For Two Samples}\label{median-test-for-two-samples}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test the two samples are drawn from the populations having the same
# medians.
#
# \textbf{Source} A random sample of \(n_1\) observations,
# \(X_1, X_2,\cdots, X_{n_1}\) drawn from a population with density
# function \(f_1(.)\) and a random sample of \(n_2\) observations,
# arranged in order of magnitude as, \(Y_1, Y_2,\cdots, Y_{n_2}\) drawn
# from another population with density function \(f_2(.)\). The population
# medians of the two populations are unknown. Let \(N = n_1 + n_2\).
#
# \textbf{Assumptions} 1. The two samples drawn are independent. 2. The
# observations must be at least ordinal. 3. The sample sizes should be
# sufficiently large.
#
# \textbf{Exmaple: } The following data give the lifetime of bulbs of two different brands. A
# sample of 7 bulbs of brand-I and a sample of 8 bulbs of brand-II is
# selected.
#
# Brand-I(X): 80 100 90 110 125 130 70
#
# Brand-II(Y): 100 120 80 140 130 160 115 120
#
# Test whether the median lifetime of two brands of bulbs are equal or not
# at 5\% level of significance.
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{3}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{H0}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the median lifetimes of two brands of bulbs are equal.}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the median lifetimes of two brands of bulbs are not equal.}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{X}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{80}\PY{p}{,}\PY{l+m+mi}{100}\PY{p}{,}\PY{l+m+mi}{90}\PY{p}{,}\PY{l+m+mi}{110}\PY{p}{,}\PY{l+m+mi}{125}\PY{p}{,}\PY{l+m+mi}{130}\PY{p}{,}\PY{l+m+mi}{70}\PY{p}{]}
# \PY{n}{Y}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{100}\PY{p}{,}\PY{l+m+mi}{120}\PY{p}{,}\PY{l+m+mi}{80}\PY{p}{,}\PY{l+m+mi}{140}\PY{p}{,}\PY{l+m+mi}{130}\PY{p}{,}\PY{l+m+mi}{160}\PY{p}{,}\PY{l+m+mi}{115}\PY{p}{,}\PY{l+m+mi}{120}\PY{p}{]}
#
# \PY{n}{stat}\PY{p}{,} \PY{n}{pval}\PY{p}{,} \PY{n}{median}\PY{p}{,} \PY{n}{cont\PYZus{}tab}\PY{o}{=}\PY{n}{ss}\PY{o}{.}\PY{n}{median\PYZus{}test}\PY{p}{(}\PY{n}{X}\PY{p}{,}\PY{n}{Y}\PY{p}{,}\PY{n}{ties}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{ignore}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Statistic = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, p\PYZhy{}value = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{stat}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Grand Median = }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{median}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Contingency table: }\PY{l+s+se}{\PYZbs{}n}\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{cont\PYZus{}tab}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Reject Ho: Therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Fail to reject Ho: Therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# Statistic = 1.143, p-value = 0.285
# Grand Median =  115.0
# Contingency table:
#  [[2 5]
#  [5 2]]
# Conclusion - Fail to reject Ho: Therefore the median lifetimes of two brands of bulbs are equal.
#     \end{Verbatim}
#
#     \hypertarget{median-test-for-two-populations}{%
# \section{Median Test For Two Populations}\label{median-test-for-two-populations}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test the two random samples could have come from two populations with
# the same frequency distribution.
#
# \textbf{Source : }Two independent random samples of sizes \(n_1\) and \(n_2\) are drawn.
#
# \textbf{Assumptions} : The sample sizes of the two samples are sufficiently large.
#
# \hypertarget{example}{%
# \textbf{Example}}: A random sample of 15 observations is drawn from a population from which
# there are 9 observations below the combined median and 6 observations
# above the combined median. Another sample of 15 observations is drawn
# from another population from which there are 6 observations below the
# combined median and 9 observations above the combined median. Examine
# whether the two random samples can be regarded as come from the
# population having the same frequency distribution. Test at 5\% level of
# significance.
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{4}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{H0}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the populations from which, the two samples drawn have the same frequency distribution.}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the populations from which, the two samples drawn have the different frequency distribution.}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{tab}\PY{o}{=}\PY{p}{[}\PY{p}{[}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{6}\PY{p}{]}\PY{p}{,}\PY{p}{[}\PY{l+m+mi}{6}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{]}\PY{p}{]}
# \PY{n}{chi2stat}\PY{p}{,}\PY{n}{pval}\PY{p}{,}\PY{n}{df}\PY{p}{,}\PY{n}{exp\PYZus{}tab}\PY{o}{=}\PY{n}{ss}\PY{o}{.}\PY{n}{chi2\PYZus{}contingency}\PY{p}{(}\PY{n}{tab}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Chi2\PYZhy{}Statistic = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, degrees of freedom = }\PY{l+s+si}{\PYZpc{}d}\PY{l+s+s1}{,p\PYZhy{}value = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{chi2stat}\PY{p}{,}\PY{n}{df}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Expected Contingency table: }\PY{l+s+se}{\PYZbs{}n}\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{exp\PYZus{}tab}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Reject Ho: Therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Fail to reject Ho: Therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# Chi2-Statistic = 0.533, degrees of freedom = 1,p-value = 0.465
# Expected Contingency table:
#  [[7.5 7.5]
#  [7.5 7.5]]
# Conclusion - Fail to reject Ho: Therefore the populations from which, the two samples drawn have the same frequency distribution.
#     \end{Verbatim}
#
#     \hypertarget{median-test-for-k-populations}{%
# \section{Median Test For K Populations}\label{median-test-for-k-populations}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test the \(K\) random samples could have come \(K\)
# \textbf{populations with the same frequency distribution}.
#
# \textbf{Source : }\(K\) independent random samples of sizes \(n_1, n_2,\cdots, n_k\) are drawn.
#
# \textbf{Assumptions : } The sample sizes of the \(K\) samples are sufficiently large.
#
# \textbf{Example : }  Five independent random samples are drawn with sizes 45, 65, 55, 85 and 62. The median of the combined
# sample is found and the number of observations above and below the median for each sample is found and is tabulated as follows. Examine
# whether the five random samples can be regarded as drawn from five populations with the same frequency distribution. Test at 5\% level of
# significance.
#
# \begin{verbatim}
#     |Samples      |1  |2  |3  |4  |5  |Total|
#     |-------------|---|---|---|---|---|-----|
#     |Above Median |20 |30 |25 |40 |30 |145  |
#     |Below Median |25 |35 |30 |45 |32 |167  |
#     |Total        |45 |65 |55 |85 |62 |312  |
# \end{verbatim}
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{5}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{H0}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the populations from which, the five samples drawn have the same frequency distribution.}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the populations from which, the five samples drawn have the different frequency distribution.}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{tab}\PY{o}{=}\PY{p}{[}\PY{p}{[}\PY{l+m+mi}{20}\PY{p}{,}\PY{l+m+mi}{30}\PY{p}{,}\PY{l+m+mi}{25}\PY{p}{,}\PY{l+m+mi}{40}\PY{p}{,}\PY{l+m+mi}{30}\PY{p}{]}\PY{p}{,}\PY{p}{[}\PY{l+m+mi}{25}\PY{p}{,}\PY{l+m+mi}{35}\PY{p}{,}\PY{l+m+mi}{30}\PY{p}{,}\PY{l+m+mi}{45}\PY{p}{,}\PY{l+m+mi}{32}\PY{p}{]}\PY{p}{]}
# \PY{n}{chi2stat}\PY{p}{,}\PY{n}{pval}\PY{p}{,}\PY{n}{df}\PY{p}{,}\PY{n}{exp\PYZus{}tab}\PY{o}{=}\PY{n}{ss}\PY{o}{.}\PY{n}{chi2\PYZus{}contingency}\PY{p}{(}\PY{n}{tab}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Chi2\PYZhy{}Statistic = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, degrees of freedom = }\PY{l+s+si}{\PYZpc{}d}\PY{l+s+s1}{,p\PYZhy{}value = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{chi2stat}\PY{p}{,}\PY{n}{df}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Expected Contingency table: }\PY{l+s+se}{\PYZbs{}n}\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{exp\PYZus{}tab}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Fail to reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# Chi2-Statistic = 0.203, degrees of freedom = 4,p-value = 0.995
# Expected Contingency table:
#  [[20.91346154 30.20833333 25.56089744 39.50320513 28.81410256]
#  [24.08653846 34.79166667 29.43910256 45.49679487 33.18589744]]
# Conclusion - Fail to reject Ho: therefore the populations from which, the five
# samples drawn have the same frequency distribution.
#     \end{Verbatim}
#
#     \hypertarget{waldwolfowitz-run-test}{%
# \section{Wald--Wolfowitz Run Test}\label{waldwolfowitz-run-test}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test the two samples have been drawn from the populations having the \textbf{same density functions}.
#
# \textbf{Definition: } (RUN) A run is defined
# as a sequence of letters of one type surrounded by a sequence of letters
# of the other type, and the number of elements in a run is referred to as
# the length of the run.
#
# \textbf{Source : }A random sample of \(n_1\) observations, arranged in order of magnitude as, \(X_1, X_2,\cdots, X_{n_1}\) drawn from a population with density function \(f_1(.)\) and a random sample of n2 observations, arranged in order of magnitude as, \(Y_1, Y_2,…, Y_{n_2}\) drawn from another population with density function \(f_2(.)\)
#
# \textbf{Assumption : }The two samples are drawn independently.
#
# \textbf{Example : } A random sample of 8 households is selected from a village, A whose daily expense on milk as 11 15 17 19 25 27 31 33. Another sample of 9 households is selected from village B whose expense on milk is 12 16 20 22 28 30 36 38 42. Test whether the households of the two villages are same on spending daily milk expenses.
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{6}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{H0}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the households of the two villages are same on spending daily milk expenses.}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the households of the two villages are not same on spending daily milk expenses.}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{sample1} \PY{o}{=} \PY{p}{[}\PY{l+m+mi}{11}\PY{p}{,}\PY{l+m+mi}{15}\PY{p}{,}\PY{l+m+mi}{17}\PY{p}{,}\PY{l+m+mi}{19}\PY{p}{,}\PY{l+m+mi}{25}\PY{p}{,}\PY{l+m+mi}{27}\PY{p}{,}\PY{l+m+mi}{31}\PY{p}{,}\PY{l+m+mi}{33}\PY{p}{]}
# \PY{n}{sample2} \PY{o}{=} \PY{p}{[}\PY{l+m+mi}{12}\PY{p}{,}\PY{l+m+mi}{16}\PY{p}{,}\PY{l+m+mi}{20}\PY{p}{,}\PY{l+m+mi}{22}\PY{p}{,}\PY{l+m+mi}{28}\PY{p}{,}\PY{l+m+mi}{30}\PY{p}{,}\PY{l+m+mi}{36}\PY{p}{,}\PY{l+m+mi}{38}\PY{p}{,}\PY{l+m+mi}{42}\PY{p}{]}
# \PY{n}{z\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{o}{=} \PY{n}{runstest\PYZus{}2samp}\PY{p}{(}\PY{n}{sample1}\PY{p}{,}\PY{n}{sample2}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Z Statistic = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, p\PYZhy{}value = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{z\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Fail to reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# Z Statistic = 0.015, p-value = 0.988
# Conclusion - Fail to reject Ho: therefore the households of the two villages are same on spending daily milk expenses.
#     \end{Verbatim}
#
#     \hypertarget{kruskallwallis-rank-sum-test-h-test}{%
# \section{Kruskall--Wallis Rank Sum Test (H Test)}\label{kruskallwallis-rank-sum-test-h-test}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test the \(K\) random samples drawn from the \(K\) populations have
# the same mean.
#
# \textbf{Source : }\(K\) random samples, each with sizes
# \(n_i\), \((i = 1, 2, \cdots, K)\) be drawn independently from \(K\)
# populations. Let \(n_1 + n_2 + \cdots + n_K = N\).
#
# \textbf{Assumptions} 1.
# The sample sizes of each sample should be at least 5. 2. The sample
# sizes need not be equal. 3. The frequency distributions of K populations
# should be continuous.
#
# \hypertarget{example}{%
# \textbf{Example}}: The following table shows three independent samples of sizes 9, 6 and 5
# drawn from three populations of children whose weight and their ranks.
# Test whether the mean weight of the children from the three populations
# is same at 5\% level of significance.
#
# Sample 1: 11.7,11.9,16.1,17.5,20.5,25.1,30.5,32.1,82.5
#
# Sample 2: 19.6,21.8,25.2,33.2,33.2,34.1
#
# Sample 3: 18.4,22.9,25.1,29.7,33.5
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{7}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{H0}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the mean weight of the children from the three populations is same.}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the mean weight of the children from the three populations is not same.}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{Sample1}\PY{o}{=}\PY{p}{[}\PY{l+m+mf}{11.7}\PY{p}{,}\PY{l+m+mf}{11.9}\PY{p}{,}\PY{l+m+mf}{16.1}\PY{p}{,}\PY{l+m+mf}{17.5}\PY{p}{,}\PY{l+m+mf}{20.5}\PY{p}{,}\PY{l+m+mf}{25.1}\PY{p}{,}\PY{l+m+mf}{30.5}\PY{p}{,}\PY{l+m+mf}{32.1}\PY{p}{,}\PY{l+m+mf}{82.5}\PY{p}{]}
# \PY{n}{Sample2}\PY{o}{=}\PY{p}{[}\PY{l+m+mf}{19.6}\PY{p}{,}\PY{l+m+mf}{21.8}\PY{p}{,}\PY{l+m+mf}{25.2}\PY{p}{,}\PY{l+m+mf}{33.2}\PY{p}{,}\PY{l+m+mf}{33.2}\PY{p}{,}\PY{l+m+mf}{34.1}\PY{p}{]}
# \PY{n}{Sample3}\PY{o}{=}\PY{p}{[}\PY{l+m+mf}{18.4}\PY{p}{,}\PY{l+m+mf}{22.9}\PY{p}{,}\PY{l+m+mf}{25.1}\PY{p}{,}\PY{l+m+mf}{29.7}\PY{p}{,}\PY{l+m+mf}{33.5}\PY{p}{]}
#
# \PY{n}{KS\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{o}{=} \PY{n}{ss}\PY{o}{.}\PY{n}{kruskal}\PY{p}{(}\PY{n}{Sample1}\PY{p}{,}\PY{n}{Sample2}\PY{p}{,}\PY{n}{Sample3}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{KS Statistic = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, p\PYZhy{}value = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{KS\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Fail to reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# KS Statistic = 2.155, p-value = 0.341
# Conclusion - Fail to reject Ho: therefore the mean weight of the children from
# the three populations is same.
#     \end{Verbatim}
#
#     \hypertarget{mannwhitneywilcoxon-rank-sum-test}{%
# \section{Mann--Whitney--Wilcoxon Rank Sum Test}\label{mannwhitneywilcoxon-rank-sum-test}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test the two random samples be drawn from the populations having the
# same mean, based on the rank sum of the sample.
#
# \textbf{Source : }A random
# sample of n1 observations, arranged in order of magnitude as,
# \(X_1, X_2,\cdots, X_{n_1}\) drawn from a population with density
# function \(f_1(.)\) and a random sample of \(n_2\) observations,
# arranged in order of magnitude as, \(Y_1, Y_2, \cdots, Y_{n_2}\) drawn
# from another population with density function \(f_2(.)\).
#
# \textbf{Assumptions} 1. The two samples drawn are independent. 2. The populations
# have continuous frequency distributions.
#
# \hypertarget{example}{%
# \textbf{Example}}: A random sample of 9 adults (of same age group) is selected from city-A
# whose weights (in kg.) is 50.5 37.5 49.8 56.0 42.0 56.0 50.0 54.0 48.0.
# Another sample of 10 adults of the same age group has the following
# weights, 57 52 51 44.2 55 62 59 45.2 53.5 44.4. Test whether the mean
# weight of the adults from the two cities is same at 5\% level of
# significance.
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{8}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{H0}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the mean weight of the adults from the two cities is same.}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the mean weight of the adults from the two cities is not same.}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{X}\PY{o}{=}\PY{p}{[}\PY{l+m+mf}{50.5}\PY{p}{,}\PY{l+m+mf}{37.5}\PY{p}{,}\PY{l+m+mf}{49.8}\PY{p}{,}\PY{l+m+mf}{56.0}\PY{p}{,}\PY{l+m+mf}{42.0}\PY{p}{,}\PY{l+m+mf}{56.0}\PY{p}{,}\PY{l+m+mf}{50.0}\PY{p}{,}\PY{l+m+mf}{54.0}\PY{p}{,}\PY{l+m+mf}{48.0}\PY{p}{]}
# \PY{n}{Y}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{57}\PY{p}{,}\PY{l+m+mi}{52}\PY{p}{,}\PY{l+m+mi}{51}\PY{p}{,}\PY{l+m+mf}{44.2}\PY{p}{,}\PY{l+m+mi}{55}\PY{p}{,}\PY{l+m+mi}{62}\PY{p}{,}\PY{l+m+mi}{59}\PY{p}{,}\PY{l+m+mf}{45.2}\PY{p}{,}\PY{l+m+mf}{53.5}\PY{p}{,}\PY{l+m+mf}{44.4}\PY{p}{]}
# \PY{n}{RS\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{o}{=} \PY{n}{ss}\PY{o}{.}\PY{n}{ranksums}\PY{p}{(}\PY{n}{X}\PY{p}{,}\PY{n}{Y}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{RS Statistic = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, p\PYZhy{}value = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{RS\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Fail to reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# RS Statistic = -1.061, p-value = 0.288
# Conclusion - Fail to reject Ho: therefore the mean weight of the adults from the
# two cities is same.
#     \end{Verbatim}
#
#     \hypertarget{mannwhitneywilcoxon-u-test}{%
# \section{Mann--Whitney—Wilcoxon U-Test}\label{mannwhitneywilcoxon-u-test}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test that the two random samples are drawn from the populations
# having the \textbf{same density functions}.
#
# \textbf{Source : }A random sample
# of n1 observations, arranged in order of magnitude as,
# \(X_1, X_2,\cdots, X_{n_1}\) drawn from a population with density
# function \(f_1(.)\) and a random sample of \(n_2\) observations,
# arranged in order of magnitude as, \(Y_1, Y_2,\cdots, Y_{n_2}\) drawn
# from another population with density function \(f_2(.)\).
#
# \textbf{Assumptions} 1. The two samples drawn are independent. 2. The populations
# have continuous frequency distributions. 3. The sample sizes should be
# sufficiently large.
#
# \hypertarget{example}{%
# \textbf{Example}}: Two independent samples of 15 students each from two universities namely
# Annamalai University (A) and Banaras Hindu University (B) are drawn. The
# scores obtained by students of the two universities in an Aptitude test
# are given below. Test whether the two samples have been drawn from the
# populations having the same distribution at 5\% level of significance.
#
# A : 920 840 780 850 830 930 800 860 760 730 740 680 670 540 710
#
# B : 870 890 620 650 700 720 750 660 810 790 950 690 640 600 770
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{9}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{H0}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the two samples have the same population distributions.}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the population distributions of the two samples are not same.}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{X}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{920}\PY{p}{,}\PY{l+m+mi}{840}\PY{p}{,}\PY{l+m+mi}{780}\PY{p}{,}\PY{l+m+mi}{850}\PY{p}{,}\PY{l+m+mi}{830}\PY{p}{,}\PY{l+m+mi}{930}\PY{p}{,}\PY{l+m+mi}{800}\PY{p}{,}\PY{l+m+mi}{860}\PY{p}{,}\PY{l+m+mi}{760}\PY{p}{,}\PY{l+m+mi}{730}\PY{p}{,}\PY{l+m+mi}{740}\PY{p}{,}\PY{l+m+mi}{680}\PY{p}{,}\PY{l+m+mi}{670}\PY{p}{,}\PY{l+m+mi}{540}\PY{p}{,}\PY{l+m+mi}{710}\PY{p}{]}
# \PY{n}{Y}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{870}\PY{p}{,}\PY{l+m+mi}{890}\PY{p}{,}\PY{l+m+mi}{620}\PY{p}{,}\PY{l+m+mi}{650}\PY{p}{,}\PY{l+m+mi}{700}\PY{p}{,}\PY{l+m+mi}{720}\PY{p}{,}\PY{l+m+mi}{750}\PY{p}{,}\PY{l+m+mi}{660}\PY{p}{,}\PY{l+m+mi}{810}\PY{p}{,}\PY{l+m+mi}{790}\PY{p}{,}\PY{l+m+mi}{950}\PY{p}{,}\PY{l+m+mi}{690}\PY{p}{,}\PY{l+m+mi}{640}\PY{p}{,}\PY{l+m+mi}{600}\PY{p}{,}\PY{l+m+mi}{770}\PY{p}{]}
# \PY{n}{MU\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{o}{=} \PY{n}{ss}\PY{o}{.}\PY{n}{mannwhitneyu}\PY{p}{(}\PY{n}{X}\PY{p}{,}\PY{n}{Y}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{MU Statistic = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, p\PYZhy{}value = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{MU\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Fail to reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# MU Statistic = 86.000, p-value = 0.140
# Conclusion - Fail to reject Ho: therefore the two samples have the same
# population distributions.
#     \end{Verbatim}
#
#     \hypertarget{kolmogorovsmirnov-test-for-goodness-of-fit}{%
# \section{Kolmogorov--Smirnov Test for Goodness of Fit}\label{kolmogorovsmirnov-test-for-goodness-of-fit}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test the population distribution \(F(x)\) be regarded as \(F_0(x)\), based on a random sample.
#
# \textbf{Source : } Let \(Xi\), \((i = 1, 2, \cdots, n)\) a random sample of \(n\) observations be drawn from a population. Let \(F_0(x)\) be the cumulative distribution of a specified (given) population.
#
# \textbf{Example : } The following is a random sample of size 20. Test whether the sample can be considered as a sample from a \(N(0,1)\) distribution.
#
# 2.240, --.400, --1.152, .980, .361, --.123, --.625, .682, 2.323,
# --1.053, --.870, --.164, --.34, --.041, 1.405, 1.187, .323, .270, -.128,
# .101
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{10}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{H0}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the given sample is drawn from a standard normal distribution.}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the given sample is not drawn from a standard normal distribution.}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{x}\PY{o}{=}\PY{p}{[}\PY{l+m+mf}{2.240}\PY{p}{,} \PY{o}{\PYZhy{}}\PY{o}{.}\PY{l+m+mi}{400}\PY{p}{,} \PY{o}{\PYZhy{}}\PY{l+m+mf}{1.152}\PY{p}{,} \PY{o}{.}\PY{l+m+mi}{980}\PY{p}{,} \PY{o}{.}\PY{l+m+mi}{361}\PY{p}{,} \PY{o}{\PYZhy{}}\PY{o}{.}\PY{l+m+mi}{123}\PY{p}{,} \PY{o}{\PYZhy{}}\PY{o}{.}\PY{l+m+mi}{625}\PY{p}{,} \PY{o}{.}\PY{l+m+mi}{682}\PY{p}{,} \PY{l+m+mf}{2.323}\PY{p}{,} \PY{o}{\PYZhy{}}\PY{l+m+mf}{1.053}\PY{p}{,}\PY{o}{\PYZhy{}}\PY{o}{.}\PY{l+m+mi}{870}\PY{p}{,} \PY{o}{\PYZhy{}}\PY{o}{.}\PY{l+m+mi}{164}\PY{p}{,} \PY{o}{\PYZhy{}}\PY{o}{.}\PY{l+m+mi}{34}\PY{p}{,} \PY{o}{\PYZhy{}}\PY{o}{.}\PY{l+m+mi}{041}\PY{p}{,} \PY{l+m+mf}{1.405}\PY{p}{,} \PY{l+m+mf}{1.187}\PY{p}{,} \PY{o}{.}\PY{l+m+mi}{323}\PY{p}{,} \PY{o}{.}\PY{l+m+mi}{270}\PY{p}{,} \PY{o}{\PYZhy{}}\PY{o}{.}\PY{l+m+mi}{128}\PY{p}{,} \PY{o}{.}\PY{l+m+mi}{101}\PY{p}{]}
#
# \PY{n}{KS\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{o}{=} \PY{n}{ss}\PY{o}{.}\PY{n}{kstest}\PY{p}{(}\PY{n}{x}\PY{p}{,}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{norm}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{KS Statistic = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, p\PYZhy{}value = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{KS\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Fail to reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# KS Statistic = 0.145, p-value = 0.797
# Conclusion - Fail to reject Ho: therefore the given sample is drawn from a standard normal distribution.
#     \end{Verbatim}
#
#     \hypertarget{kolmogorovsmirnov-test-for-comparing-two-populations}{%
# \section{Kolmogorov--Smirnov Test For Comparing Two Populations}\label{kolmogorovsmirnov-test-for-comparing-two-populations}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test the two population distributions are identical, based on the two
# sample distributions.
#
# \textbf{Source : }Let \(X_i, (i = 1, 2,\cdots, n)\) be a
# random sample of \(n\) observations be drawn from a population. Let
# \(Y_i, (i = 1, 2,\cdots, n)\) be a random sample of $n$ observations be
# drawn from another population.
#
# \textbf{Example} The following data denotes
# the lifetime of bulbs of two different brands. Test whether the brands
# differ with respect to average life.
#
# Brand-I: 80 100 90 110 125 130 70
#
# Brand-II: 100 120 80 140 130 160 115 120
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{11}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{H0}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the average lifetimes of two brands of bulbs are equal.}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the average lifetimes of two brands of bulbs are not equal.}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{Brand1}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{80}\PY{p}{,}\PY{l+m+mi}{100}\PY{p}{,}\PY{l+m+mi}{90}\PY{p}{,}\PY{l+m+mi}{110}\PY{p}{,}\PY{l+m+mi}{125}\PY{p}{,}\PY{l+m+mi}{130}\PY{p}{,}\PY{l+m+mi}{70}\PY{p}{]}
# \PY{n}{Brand2}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{100}\PY{p}{,}\PY{l+m+mi}{120}\PY{p}{,}\PY{l+m+mi}{80}\PY{p}{,}\PY{l+m+mi}{140}\PY{p}{,}\PY{l+m+mi}{130}\PY{p}{,}\PY{l+m+mi}{160}\PY{p}{,}\PY{l+m+mi}{115}\PY{p}{,}\PY{l+m+mi}{120}\PY{p}{]}
#
# \PY{n}{KS\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{o}{=} \PY{n}{ss}\PY{o}{.}\PY{n}{ks\PYZus{}2samp}\PY{p}{(}\PY{n}{Brand1}\PY{p}{,}\PY{n}{Brand2}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{KS Statistic = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, p\PYZhy{}value = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{KS\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Fail to reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# KS Statistic = 0.464, p-value = 0.313
# Conclusion - Fail to reject Ho: therefore the average lifetimes of two brands of bulbs are equal.
#     \end{Verbatim}
#
#     \hypertarget{spearman-rank-correlation-test}{%
# \section{Spearman Rank Correlation Test}\label{spearman-rank-correlation-test}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test the existence of \textbf{correlation between the two pairs of
# observations} in the population based on a sample.
#
# \textbf{Source : }Let \((X_i, Y_i), i = 1, 2, \cdots, n\) be a random sample of n pairs of
# observations drawn.
#
# \textbf{Assumptions} 1. The population distribution is continuous. 2. The observations should be obtained in pairs.
#
# \hypertarget{example}{%
# \textbf{Example}}: Two Judges have ranked the ten competitors those who attended a beauty
# competition as follows. Test whether the rank correlation between the
# two judges is significant or not at 5\% level of significance.
#
# Judge-I: 2 4 7 8 3 1 5 9 10 6
#
# Judge-II: 3 5 6 7 2 1 4 8 9 10
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{12}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{H0}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{there is no correlation between the two judges in the competition.}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{there exists correlation between the two judges in the competition.}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{Judge1}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{2}\PY{p}{,}\PY{l+m+mi}{4}\PY{p}{,}\PY{l+m+mi}{7}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{3}\PY{p}{,}\PY{l+m+mi}{1}\PY{p}{,}\PY{l+m+mi}{5}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{6}\PY{p}{]}
# \PY{n}{Judge2}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{3}\PY{p}{,}\PY{l+m+mi}{5}\PY{p}{,}\PY{l+m+mi}{6}\PY{p}{,}\PY{l+m+mi}{7}\PY{p}{,}\PY{l+m+mi}{2}\PY{p}{,}\PY{l+m+mi}{1}\PY{p}{,}\PY{l+m+mi}{4}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{]}
#
# \PY{n}{SperCorr}\PY{p}{,}\PY{n}{pval}\PY{o}{=}\PY{n}{ss}\PY{o}{.}\PY{n}{spearmanr}\PY{p}{(}\PY{n}{Judge1}\PY{p}{,}\PY{n}{Judge2}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Sperman Correlation Coeffitient = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, p\PYZhy{}value = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{SperCorr}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Fail to reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# Sperman Correlation Coeffitient = 0.855, p-value = 0.002
# Conclusion - Reject Ho: therefore there exists correlation between the two judges in the competition.
#     \end{Verbatim}
#
#     \hypertarget{test-for-randomness}{%
# \section{Test for Randomness}\label{test-for-randomness}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test the order of observations in a \textbf{sample is random},
# obtained from any experiment.
#
# \textbf{Source : }A sample of n observations is
# drawn from any experiment.
#
# \textbf{Assumptions} 1. The sample observations be obtained under similar conditions. 2. Retain the observations in the
# order in which they occur. That is, \(X_i\) is the ith observation in the outcome of an experiment.
#
# \hypertarget{example}{%
# \textbf{Example}}: The following data denotes the length of iron rods (in cms.) of a sample
# of 24 units manufactured by an industry. Test whether the sample drawn
# is random at 10\% level of significance.
#
# 21.02 20.08 20.05 19.70 19.13 17.09 20.09 19.40 20.56 20.97 20.17 21.35
# 19.64 20.82 21.26 20.75 20.74 21.59 20.75 21.01 19.09 18.73 18.45 19.80
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{13}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{H0}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the sample observations obtained is random.}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{the sample observations obtained is not at random.}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{x}\PY{o}{=}\PY{p}{[}\PY{l+m+mf}{21.02}\PY{p}{,}\PY{l+m+mf}{20.08}\PY{p}{,}\PY{l+m+mf}{20.05}\PY{p}{,}\PY{l+m+mf}{19.70}\PY{p}{,}\PY{l+m+mf}{19.13}\PY{p}{,}\PY{l+m+mf}{17.09}\PY{p}{,}\PY{l+m+mf}{20.09}\PY{p}{,}\PY{l+m+mf}{19.40}\PY{p}{,}\PY{l+m+mf}{20.56}\PY{p}{,}\PY{l+m+mf}{20.97}\PY{p}{,}\PY{l+m+mf}{20.17}\PY{p}{,}\PY{l+m+mf}{21.35}\PY{p}{,}
#    \PY{l+m+mf}{19.64}\PY{p}{,}\PY{l+m+mf}{20.82}\PY{p}{,}\PY{l+m+mf}{21.26}\PY{p}{,}\PY{l+m+mf}{20.75}\PY{p}{,}\PY{l+m+mf}{20.74}\PY{p}{,}\PY{l+m+mf}{21.59}\PY{p}{,}\PY{l+m+mf}{20.75}\PY{p}{,}\PY{l+m+mf}{21.01}\PY{p}{,}\PY{l+m+mf}{19.09}\PY{p}{,}\PY{l+m+mf}{18.73}\PY{p}{,}\PY{l+m+mf}{18.45}\PY{p}{,}\PY{l+m+mf}{19.80}\PY{p}{]}
#
# \PY{n}{z\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{o}{=} \PY{n}{runstest\PYZus{}1samp}\PY{p}{(}\PY{n}{x}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Z Statistic = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, p\PYZhy{}value = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{z\PYZus{}stat}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Fail to reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# Z Statistic = -2.713, p-value = 0.007
# Conclusion - Reject Ho: therefore the sample observations obtained is not at
# random.
#     \end{Verbatim}
#
#     \hypertarget{friedmans-test-for-multiple-tretment-of-a-series-of-objects}{%
# \section{Friedman's Test For Multiple Treatment of a Series of Objects}\label{friedmans-test-for-multiple-tretment-of-a-series-of-objects}}
#
# \hypertarget{aim}{%
# \textbf{Aim}} : To test the significance of the differences in response for K treatments applied to n subjects.
#
# \textbf{Source : }The data are obtained as a two-way
# table having n rows (subjects) and K columns (treatments).
#
# \textbf{Assumptions : } 1. The response to one treatment by a subject is not
# affected by the same subject's response to another treatment. 2. The
# response distribution is continuous for each subject.
#
# \hypertarget{example}{%
# \textbf{Example}}: Four experts were appointed to conduct an interview board. There are
# fifteen candidates attended the interview. The following are the points
# given to the candidates by the experts. Test whether the points given by
# the experts to the candidates are significant at 5\% level of
# significance
#
# \begin{verbatim}
# | Candidate | C1 | C2 | C3 | C4 |
# |:---------:|:--:|:--:|:--:|:--:|
# |     1     |  8 |  8 | 10 | 10 |
# |     2     |  7 |  9 |  9 |  9 |
# |     3     | 10 |  8 |  8 | 10 |
# |     4     |  8 |  8 | 10 | 10 |
# |     5     |  9 |  9 |  9 | 10 |
# |     6     |  9 |  9 | 10 |  9 |
# |     7     |  8 |  9 |  8 |  9 |
# |     8     |  8 |  8 |  8 |  8 |
# |     9     |  9 |  9 | 10 |  9 |
# |     10    |  9 |  9 |  9 |  9 |
# |     11    |  9 | 10 |  9 | 10 |
# |     12    |  7 |  9 |  9 |  9 |
# |     13    | 10 | 10 | 10 | 10 |
# |     14    |  9 |  9 |  9 | 10 |
# |     15    |  7 | 10 | 10 | 10 |
# \end{verbatim}
#
#     \begin{tcolorbox}[breakable, size=fbox, boxrule=1pt, pad at break*=1mm,colback=cellbackground, colframe=cellborder]
# \prompt{In}{incolor}{14}{\boxspacing}
# \begin{Verbatim}[commandchars=\\\{\}]
# \PY{n}{H0}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{The points given by the experts to the candidates are not significant.}\PY{l+s+s2}{\PYZdq{}}
# \PY{n}{H1}\PY{o}{=}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{The points given by the experts to the candidates are significant.}\PY{l+s+s2}{\PYZdq{}}
#
# \PY{n}{candidate}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{1}\PY{p}{,}\PY{l+m+mi}{2}\PY{p}{,}\PY{l+m+mi}{3}\PY{p}{,}\PY{l+m+mi}{4}\PY{p}{,}\PY{l+m+mi}{5}\PY{p}{,}\PY{l+m+mi}{6}\PY{p}{,}\PY{l+m+mi}{7}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{11}\PY{p}{,}\PY{l+m+mi}{12}\PY{p}{,}\PY{l+m+mi}{13}\PY{p}{,}\PY{l+m+mi}{14}\PY{p}{,}\PY{l+m+mi}{15}\PY{p}{]}
# \PY{n}{c1}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{7}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{7}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{7}\PY{p}{]}
# \PY{n}{c2}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{]}
# \PY{n}{c3}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{]}
# \PY{n}{c4}\PY{o}{=}\PY{p}{[}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{8}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{9}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{,}\PY{l+m+mi}{10}\PY{p}{]}
#
# \PY{n}{stats}\PY{p}{,} \PY{n}{pval}\PY{o}{=}\PY{n}{ss}\PY{o}{.}\PY{n}{friedmanchisquare}\PY{p}{(}\PY{n}{c1}\PY{p}{,}\PY{n}{c2}\PY{p}{,}\PY{n}{c3}\PY{p}{,}\PY{n}{c4}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Friedman Statistic = }\PY{l+s+si}{\PYZpc{}0.3f}\PY{l+s+s1}{, p\PYZhy{}value = }\PY{l+s+si}{\PYZpc{}.3f}\PY{l+s+s1}{\PYZsq{}}\PY{o}{\PYZpc{}}\PY{p}{(}\PY{n}{stat}\PY{p}{,}\PY{n}{pval}\PY{p}{)}\PY{p}{)}
#
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{Conclusion \PYZhy{} }\PY{l+s+s1}{\PYZsq{}}\PY{p}{,}\PY{n}{end}\PY{o}{=}\PY{l+s+s1}{\PYZsq{}}\PY{l+s+s1}{\PYZsq{}}\PY{p}{)}
# \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H1}\PY{p}{)} \PY{k}{if} \PY{n}{pval}\PY{o}{\PYZlt{}}\PY{n}{alpha} \PY{k}{else} \PY{n+nb}{print}\PY{p}{(}\PY{l+s+s2}{\PYZdq{}}\PY{l+s+s2}{Fail to reject Ho: therefore}\PY{l+s+s2}{\PYZdq{}}\PY{p}{,}\PY{n}{H0}\PY{p}{)}
# \end{Verbatim}
# \end{tcolorbox}
#
#     \begin{Verbatim}[commandchars=\\\{\}]
# Friedman Statistic = 1.143, p-value = 0.006
# Conclusion - Reject Ho: therefore The points given by the experts to the candidates are significant.
#     \end{Verbatim}
