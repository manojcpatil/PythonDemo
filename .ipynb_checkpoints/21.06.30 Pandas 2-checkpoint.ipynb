# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Merge

# %% [markdown]
# Concat
# pandas provides various facilities for easily combining together Series and DataFrame objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.334106  2.573985 -0.033415 -0.368160
# 1  0.910806  0.226059 -1.564074  0.190220
# 2  1.491893 -1.068702 -0.227191  1.318969
# 3 -0.306719  0.606535  2.187004 -1.973585
# 4 -0.090972  1.257914  0.299857 -0.117149
# 5 -2.854189  0.107293 -0.770414  0.878010
# 6 -0.987459 -0.649522  0.099402  0.096287
# 7 -0.349077 -0.940501 -1.245312  0.653381
# 8  0.383872  1.219230  0.637059 -0.175310
# 9  0.413260 -1.309039 -0.492849  1.059630

# %%
pieces = [df[:3], df[7:]]

# %%
pieces
# Out:
# [          0         1         2         3
#  0  0.334106  2.573985 -0.033415 -0.368160
#  1  0.910806  0.226059 -1.564074  0.190220
#  2  1.491893 -1.068702 -0.227191  1.318969,
#            0         1         2         3
#  7 -0.349077 -0.940501 -1.245312  0.653381
#  8  0.383872  1.219230  0.637059 -0.175310
#  9  0.413260 -1.309039 -0.492849  1.059630]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.334106  2.573985 -0.033415 -0.368160
# 1  0.910806  0.226059 -1.564074  0.190220
# 2  1.491893 -1.068702 -0.227191  1.318969
# 7 -0.349077 -0.940501 -1.245312  0.653381
# 8  0.383872  1.219230  0.637059 -0.175310
# 9  0.413260 -1.309039 -0.492849  1.059630

# %%
a=pd.DataFrame(np.random.randn(2, 4))
b=pd.DataFrame(np.random.randn(3, 4))

# %%
pd.concat([a,b])
# Out:
#           0         1         2         3
# 0  0.447846  1.274992 -1.097367  1.237383
# 1 -0.082763 -0.522596 -1.772287  0.354947
# 0  0.609736 -0.713565 -0.136247 -1.331574
# 1 -0.193530 -0.187998  0.351582 -0.291964
# 2 -0.451108  0.189331 -0.104071 -0.028086

# %% [markdown]
# Join

# %%
left = pd.DataFrame({"A":[1,2,3],
                     "B":[3,4,5]})
right = pd.DataFrame({"A":[1,3,4],
                     "D":[3,4,6]})
print("Left\n",left)
print("Right\n",right)
pd.merge(left,right,on="A")
# Out:
# Left
#     A  B
# 0  1  3
# 1  2  4
# 2  3  5
# Right
#     A  D
# 0  1  3
# 1  3  4
# 2  4  6
#    A  B  D
# 0  1  3  3
# 1  3  5  4

# %% [markdown]
# Dropping Entries from an Axis
# The drop method will return a new object with the indicated value or values deleted from
# an axis:

# %%
obj = pd.Series(np.arange(5.), index=['a', 'b', 'c', 'd', 'e'])
obj
new_obj = obj.drop('c')
new_obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj = pd.DataFrame(np.random.randn(3,5),columns=['a', 'b', 'c', 'd', 'e'],index=[1,2,3])
obj
new_obj = obj.drop('c',axis=1)
new_obj
# Out:
#           a         b         d         e
# 1  0.766119  0.318951 -1.896505 -1.010451
# 2  1.125115 -0.598358  0.050202  1.456658
# 3  1.455341  0.254131 -2.320190 -0.342901

# %% [markdown]
# Grouping
# By “group by” we are referring to a process involving one or more of the following steps:
#
# Splitting the data into groups based on some criteria
#
# Applying a function to each group independently
#
# Combining the results into a data structure

# %%
df = pd.DataFrame(
   ....:     {
   ....:         "Gender": ["M", "F"]*4,
   ....:         "Smoke": ["Smoker", "NonSmoker", "Nonsmoker", "Smoker"]*2,
   ....:         "ConcA": np.random.randn(8),
   ....:         "ConcB": np.random.randn(8),
   ....:     }
   ....: )

# %%
df
# Out:
#   Gender      Smoke     ConcA     ConcB
# 0      M     Smoker -0.726843  0.573400
# 1      F  NonSmoker -0.919041  0.164240
# 2      M  Nonsmoker  1.147008 -0.335627
# 3      F     Smoker -0.417063  1.993460
# 4      M     Smoker  1.192354 -0.961254
# 5      F  NonSmoker -1.329542  1.344156
# 6      M  Nonsmoker  0.844269 -0.584570
# 7      F     Smoker  0.068238  0.488485

# %%
df.groupby("Gender").sum()
# Out:
#            ConcA     ConcB
# Gender
# F      -2.597409  3.990340
# M       2.456789 -1.308051

# %%
df.groupby("Gender").mean()
# Out:
#            ConcA     ConcB
# Gender
# F      -0.649352  0.997585
# M       0.614197 -0.327013

# %%
df.groupby(["Gender", "Smoke"]).mean()
# Out:
#                      ConcA     ConcB
# Gender Smoke
# F      NonSmoker -1.124292  0.754198
#        Smoker    -0.174413  1.240972
# M      Nonsmoker  0.995639 -0.460098
#        Smoker     0.232756 -0.193927

# %%
df2=df.iloc[:,2:]
df2.apply(sum) # Column Sum
# Out:
# ConcA   -0.14062
# ConcB    2.68229
# dtype: float64

# %%
df2.apply(sum,axis=1) # Row Sum
# Out:
# 0   -0.153443
# 1   -0.754802
# 2    0.811381
# 3    1.576397
# 4    0.231101
# 5    0.014614
# 6    0.259699
# 7    0.556723
# dtype: float64

# %%
f = lambda x: x.max() - x.min()

# %%
df2.apply(f)
# Out:
# ConcA    2.521897
# ConcB    2.954713
# dtype: float64

# %%
def f2(x):
    return pd.Series([x.min(), x.max()], index=['min', 'max'])

# %%
df2.apply(f2)
# Out:
#         ConcA     ConcB
# min -1.329542 -0.961254
# max  1.192354  1.993460

# %%
df2.apply(f2,axis=1)
# Out:
#         min       max
# 0 -0.726843  0.573400
# 1 -0.919041  0.164240
# 2 -0.335627  1.147008
# 3 -0.417063  1.993460
# 4 -0.961254  1.192354
# 5 -1.329542  1.344156
# 6 -0.584570  0.844269
# 7  0.068238  0.488485

# %% [markdown]
# Element-wise Python functions can be used, too. Suppose you wanted to compute a
# formatted string from each floating-point value in frame. You can do this with apply
# map:

# %%
format = lambda x: '%.3f' % x
df2.applymap(format)
# Out:
#     ConcA   ConcB
# 0  -0.727   0.573
# 1  -0.919   0.164
# 2   1.147  -0.336
# 3  -0.417   1.993
# 4   1.192  -0.961
# 5  -1.330   1.344
# 6   0.844  -0.585
# 7   0.068   0.488

# %% [markdown]
# The reason for the name applymap is that Series has a map method for applying an
# element-wise function:

# %%
df2['ConcA'].map(format)
# Out:
# 0    -0.727
# 1    -0.919
# 2     1.147
# 3    -0.417
# 4     1.192
# 5    -1.330
# 6     0.844
# 7     0.068
# Name: ConcA, dtype: object

# %% [markdown]
# Sorting and Ranking

# %%
obj = pd.Series(range(4), index=['d', 'a', 'b', 'c'])
obj.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
obj.sort_index(ascending=False)
# Out:
# d    0
# c    3
# b    2
# a    1
# dtype: int64

# %%
# To sort a Series by its values, use its sort_values method:
obj = pd.Series([4, 7, -3, 2])
obj.sort_values()
# Out:
# 2   -3
# 3    2
# 0    4
# 1    7
# dtype: int64

# %%
# Any missing values are sorted to the end of the Series by default:
obj = pd.Series([4, np.nan, 7, np.nan, -3, 2])
obj.sort_values()
# Out:
# 4   -3.0
# 5    2.0
# 0    4.0
# 2    7.0
# 1    NaN
# 3    NaN
# dtype: float64

# %% [markdown]
# When sorting a DataFrame, you can use the data in one or more columns as the sort
# keys. To do so, pass one or more column names to the by option of sort_values:

# %%
frame = pd.DataFrame({'b': [4, 7, -3, 2], 'a': [0, 1, 0, 1]})

# %%
frame
# Out:
#    b  a
# 0  4  0
# 1  7  1
# 2 -3  0
# 3  2  1

# %%
frame.sort_values(by='b')
# Out:
#    b  a
# 2 -3  0
# 3  2  1
# 0  4  0
# 1  7  1

# %%
Ranking assigns ranks from one through the number of valid data points in an array.
The rank methods for Series and DataFrame are the place to look; by default rank
breaks ties by assigning each group the mean rank:

# %%
obj = pd.Series([7, -5, 7, 4, 2, 0, 4])
obj.rank()
# Out:
# 0    6.5
# 1    1.0
# 2    6.5
# 3    4.5
# 4    3.0
# 5    2.0
# 6    4.5
# dtype: float64

# %%
import csv

# %%
data=pd.read_csv("amoxilin.csv",index_col=["Subject","Formulation","Period"])

# %%
data.groupby(["Formulation","Period"]).describe().T
# Out:
# Formulation  Reference                  Test
# Period               1          2          1          2
# 0  count     12.000000  12.000000  12.000000  12.000000
#    mean       0.000000   0.000000   0.000000   0.000000
#    std        0.000000   0.000000   0.000000   0.000000
#    min        0.000000   0.000000   0.000000   0.000000
#    25%        0.000000   0.000000   0.000000   0.000000
# ...                ...        ...        ...        ...
# 12 min        0.160540   0.180864   0.099486   0.254603
#    25%        0.218116   0.352799   0.308552   0.314217
#    50%        0.370328   0.374830   0.333297   0.393099
#    75%        0.444776   0.443127   0.378781   0.428340
#    max        0.498490   0.448010   0.461331   0.455674
#
# [128 rows x 4 columns]

# %%
main_data=data.iloc[:,3:]

# %%
main_data
# Out:
#     0       0.5         1      1.25       1.5       1.75          2  \
# 1   0  1.652340  2.384981  3.780645  5.517781   8.609406  10.422649
# 2   0  1.032693  2.219324  3.818052  4.937696   6.574222   5.941353
# 3   0  1.130816  1.415226  2.168639  3.389043   8.016167   7.603657
